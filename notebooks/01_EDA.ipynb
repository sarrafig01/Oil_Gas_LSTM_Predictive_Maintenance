# %% [markdown]
# # Exploratory Data Analysis (EDA)
# NASA CMAPSS Dataset adapted for Oil & Gas equipment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_cmapss

df = load_cmapss('../data/train_FD001.txt')
df.head()

# %%
df.groupby('engine_id')['cycle'].max().hist()
plt.title('Equipment Lifetime Distribution')
plt.show()
